# %% [markdown]
# Created by Alberto Ueda on 2017-02-17

# %% [markdown]
# ## Loading Libs and Data

# %%
N_AUTHORS = None

# %pylab inline

import sys
sys.path.append('../../../../../ufmg-latin/pscore/rfs/')

import rfslib.rankmodels
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

import rfslib.datasets
dataset = rfslib.datasets.DBLPDataset('../../../../../pscore/datasets/',nauthors=N_AUTHORS)
dataset.prepare()
venuerank  = dataset.dfvenues.copy()
authorrank = dataset.dfauthors.copy()
grouprank  = dataset.dfgroups.copy()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# (1595771, 1) authors
# (1595771, 1) authors loaded

# %%
import rfslib.pscorefactory
pscore = rfslib.pscorefactory.PScoreRankFactory(dataset,cpp=True,ranksize=100,fullrank=False)

# %% [markdown]
# ## Filtering Venues

# %%
# %%time
vap = dataset.dfvenuesauthorpaper.copy()

def live_venues_in(year):
    return vap[vap.Year >= year].drop_duplicates('Vkey').Vkey.tolist()

def dead_venues_in(year):
    live = live_venues_in(year)
    dead = vap[~vap.Vkey.isin(live)].drop_duplicates('Vkey').Vkey.tolist()
    return dead

def venues_with_min_psize(min_papers):
    count = vap.drop_duplicates('PID').groupby('Vkey').PID.count()
    return count[count > min_papers].index.tolist()

def valid_vkeys(year, min_papers):
    big = set(venues_with_min_psize(min_papers))
    dead = set(dead_venues_in(year))
    
    return big.difference(dead)
    
valid_vkeys(2014, 10000)
# Out:
# {'conf/chi',
#  'conf/globecom',
#  'conf/hci',
#  'conf/hicss',
#  'conf/icassp',
#  'conf/icc',
#  'conf/icip',
#  'conf/icra',
#  'conf/igarss',
#  'conf/interspeech',
#  'conf/iros',
#  'conf/iscas',
#  'conf/vtc',
#  'journals/amc',
#  'journals/bioinformatics',
#  'journals/cacm',
#  'journals/corr',
#  'journals/dm',
#  'journals/ieicet',
#  'journals/tcs',
#  'journals/tit',
#  'journals/tsp'}

# %%
# %%time
valid_venues = valid_vkeys(year=2012, min_papers=100)
print len(valid_venues)
# Out:
# 2690
# CPU times: user 2.91 s, sys: 220 ms, total: 3.13 s
# Wall time: 3.13 s

# %% [markdown]
# ## Venues' Qualis, h-index and citations

# %%
import venue.qualis
from venue.qualis import qualis

venuerank['Qualis'] = venuerank.Vkey.map(lambda vkey: qualis.get_qualis_dblp('dblp:'+vkey))
venuerank['QualisRel'] = pd.Series()
venuerank['QualisRel'] = venuerank['Qualis'].replace(
    {'A1':7,'A2':6,'B1':5,'B2':4,'B3':3,'B4':2,'B5':1,'C ':0,np.nan:0})
print venuerank['QualisRel'].unique()

dfgsvenues = pd.read_csv('../data/dblp-gs-venues.csv',index_col=0)
dfgsvenues.rename(columns={'GSHindex':'H-Index'},inplace=True)
if 'H-Index' in venuerank.columns:
    del venuerank['H-Index']
venuerank = venuerank.reset_index().set_index('Vkey').join(dfgsvenues['H-Index']).reset_index().set_index('index')

vkey_cits = pd.read_csv('../data/vkey_cits.csv',index_col=0,names=['Vkey','Vcits']) # TODO by year
venuerank = venuerank.reset_index().set_index('Vkey')
venuerank['Citations'] = vkey_cits['Vcits']
venuerank = venuerank.reset_index().set_index('index')

venuerank.sort_values(by='H-Index',ascending=False).head()
# Out:
# venue/qualis/qualis.py:44: RuntimeWarning: Argument <type 'str'> is not an unicode object. Passing an encoded string will likely have unexpected results.
#   df['Key'] = df.Sigla.apply( lambda s : unidecode(s.strip('\xc2\xa0')).upper() )
# venue/qualis/qualis.py:19: RuntimeWarning: Argument <type 'str'> is not an unicode object. Passing an encoded string will likely have unexpected results.
#   title = unidecode(title)
# (1703, 5)
# 1703
# (2278, 6)
# (1317, 6)
# (1629, 6)
# [ 0.  5.  7.  6.  3.  4.  2.  1.]
#                    Vkey  VPsize  VPyear Qualis  QualisRel  H-Index  Citations
# index
# 5763    journals/nature     1.0  2007.0   None        0.0    355.0        NaN
# 5718   journals/science     1.0  1983.0   None        0.0    311.0     2481.0
# 587        journals/nar  5753.0  1975.0     B1        5.0    164.0   803995.0
# 4714           conf/and    32.0  2009.0   None        0.0    162.0      142.0
# 5246           conf/sci    28.0  1999.0   None        0.0    136.0       84.0

# %%
# Returns 3 rankings: venues, authors and groups
# Calculate the rankings based on previous rankings, 
def run_pscore(params,venuerank,authorrank,grouprank,field):
    
    dranks = pscore.rank(params)
    vrank,arank,grank = dranks['venues'],dranks['authors'],dranks['groups']
    vscore,ascore,gscore = vrank['Score'],arank['Score'],grank['Score']

    # add new score to dfrank with the name 'field' 
    rfslib.rankmodels.addscore(venuerank, vscore,field)
    rfslib.rankmodels.addscore(authorrank,ascore,field)
    rfslib.rankmodels.addscore(grouprank, gscore,field)
    
    return vrank,arank,grank

def head_ranks(n=5): 
    print vrank.sort_values(by='Score',ascending=False).head(n), '\n\n', 
    print arank.sort_values(by='Score',ascending=False).head(n), '\n\n', 
    print grank.sort_values(by='Score',ascending=False).head(n)

# %% [markdown]
# ## Ranking Functions

# %%
# Returns 3 rankings: venues, authors and groups
# Calculate the rankings based on previous rankings, 
def run_pscore(params,venuerank,authorrank,grouprank,field):
    
    dranks = pscore.rank(params)
    vrank,arank,grank = dranks['venues'],dranks['authors'],dranks['groups']
    vscore,ascore,gscore = vrank['Score'],arank['Score'],grank['Score']

    # add new score to dfrank with the name 'field' 
    rfslib.rankmodels.addscore(venuerank, vscore,field)
    rfslib.rankmodels.addscore(authorrank,ascore,field)
    rfslib.rankmodels.addscore(grouprank, gscore,field)

    return vrank,arank,grank

def rank_subarea(subarea, seeds, n=0, only_valid_venues=False):
    refvenues = [ dataset.dfvenues[dataset.dfvenues.Vkey==vkey].index[0] for vkey in seeds ]
    params = dict(area=1,model='P-score',year=(1940,2015),refvenues=refvenues,top_authors=200)

    run_pscore(params, venuerank, authorrank, grouprank, subarea)
    
    rankings = concat_rankings(subarea, venuerank, n, only_valid_venues)
    rankings.to_csv('output/subareas_rankings/' + subarea + '.csv')    
    
    return rankings

# %%
# Rank the venues using two different features and concatenate the rankings side-by-side
def concat_rankings(subarea, venuerank, n, only_valid_venues=False):

    # venuerank = venuerank[venuerank['Vkey'] == 'conf/icip'] # For quick tests
    
    pscorerank = venuerank[['Vkey', 'VPsize', 'Citations', 'Qualis', 'H-Index', subarea]
                          ].sort_values(by=subarea, ascending=False)

    # Filtering Venues by recency and min-publications
    if (only_valid_venues):
        pscorerank = pscorerank[pscorerank.Vkey.isin(valid_venues)]
    
    # P-score ranking (2nd to appear)
    pscorerank.index = range(1, pscorerank.shape[0] + 1)
    pscorerank['Rank'] = pscorerank.index
    pscorerank.rename(columns={subarea:'P-score'}, inplace=True)
    pscorerank[''] = ""
    emptycol = pscorerank['']

    # H-index ranking (same venues ranked by previous P-score) (1st to appear)
    hindexrank = pscorerank.sort_values(by='H-Index', ascending=False)
    hindexrank['Rank'] = range(1, hindexrank.shape[0] + 1)
    hindexrank.set_index('Rank', inplace=True)
    hindexrank.rename(columns={'P-score':'P-score_'}, inplace=True)
    pscorerank = pscorerank[['Rank', 'Vkey', 'Qualis', 'P-score']]
    all_rankings = pd.concat([hindexrank, pscorerank], axis=1)

    # 3rd raking: P-score / N. Publications 
    psvpranking = hindexrank
    psvpranking['PS/VP'] = psvpranking['P-score_'] / psvpranking['VPsize']
    psvpranking = psvpranking.sort_values(by='PS/VP', ascending=False)
    psvpranking.index = range(1, psvpranking.shape[0] + 1)
    psvpranking['Rank'] = psvpranking.index
    psvpranking = psvpranking[['Rank', 'Vkey', 'Qualis', 'PS/VP']]
    all_rankings = pd.concat([all_rankings, emptycol, psvpranking], axis=1)
    del all_rankings['P-score_']
    
    return all_rankings.head(n)

# %%
def rank(subarea_seeds):
        
    # Testing Vkeys
    keys_for_test = [vkey for sublist in subarea_seeds.values() for vkey in sublist]
    dead_venues = dead_venues_in(2010)
    big_venues = venues_with_min_psize(100)

    for vkey in keys_for_test:
        if (vkey not in dataset.dfvenues.Vkey.values):
            print 'Venue not found:', vkey         

        elif (vkey in dead_venues):
            print 'Dead venue:', vkey     

        elif (vkey not in big_venues):
            print 'Venue without a min of papers:', vkey            

        else:
            print vkey, ": OK"

    rankingsize = 1000
    subarea = subarea_seeds.items()[0][0]
    seeds = subarea_seeds.items()[0][1]
        
    return rank_subarea(subarea, seeds, rankingsize, True)#.ix[:,6:].copy()

# %% [markdown]
# ## Rank!

# %%
# Main Conferences
#   'conf/cvpr'
#   'journals/pami'
#   'conf/iccv'
#   'journals/ijcv'

# %% [markdown]
# ### conf/cvpr and journals/pami

# %%
subarea_seeds = {
    'Computer vision (Tests 1)':['conf/cvpr', 'journals/pami'],
}

rank(subarea_seeds).head(50)
# Out:
# conf/cvpr : OK
# journals/pami : OK
#                       Vkey   VPsize  Citations Qualis  H-Index    Rank  \
# Rank
# 1             journals/nar   5753.0   803995.0     B1    164.0       1
# 2                conf/balt    232.0      827.0   None    132.0       2
# 3                conf/cvpr   6874.0   379400.0     A1    118.0       3
# 4             journals/cce   2581.0    35527.0   None    118.0       4
# 5              journals/pr   6744.0   201239.0     A1    118.0       5
# 6             journals/cma   4572.0    33510.0   None    118.0       6
# 7             journals/cee   1272.0     4934.0   None    118.0       7
# 8      journals/neuroimage   6390.0   202819.0   None    117.0       8
# 9                conf/mmar    518.0      135.0   None    113.0       9
# 10              conf/icete    769.0     1194.0     B4     94.0      10
# 11    journals/information    150.0      275.0   None     93.0      11
# 12           journals/eswa   8936.0   109580.0     A1     89.0      12
# 13            journals/scl   1739.0    26654.0   None     89.0      13
# 14     journals/automatica   7338.0   229957.0     A1     86.0      14
# 15             journals/cm   1467.0     7672.0     A1     86.0      15
# 16          journals/pieee   1039.0    18961.0     A1     85.0      16
# 17         journals/sigpro   4742.0    50775.0     A1     84.0      17
# 18                conf/www   4501.0   120253.0     A1     83.0      18
# 19            journals/www    423.0     7421.0     B1     83.0      19
# 20             journals/or    324.0     1008.0   None     81.0      20
# 21         journals/ploscb   3878.0    85175.0   None     80.0      21
# 22       conf/coordination    377.0     6017.0   None     78.0      22
# 23            conf/infocom   6943.0   350398.0     A1     76.0      23
# 24       journals/computer   4766.0   261329.0   None     76.0      24
# 25          journals/bmcbi   7074.0   136587.0     A1     73.0      25
# 26             journals/ml   1309.0   184440.0     A1     73.0      26
# 27             journals/is   1504.0    32461.0     A2     72.0      27
# 28              conf/dasip    258.0      161.0   None     70.0      28
# 29           journals/isci   7032.0   124049.0     A1     70.0      29
# 30           journals/bise    313.0     1427.0   None     70.0      30
# 31               conf/icml   3294.0   290468.0     A1     69.0      31
# 32               conf/data    130.0       26.0   None     69.0      32
# 33         journals/orgsci    621.0    19294.0   None     68.0      33
# 34               conf/nips   5684.0   404822.0     A1     66.0      34
# 35           journals/jocn   2068.0    89870.0   None     64.0      35
# 36     journals/interfaces    714.0     4506.0     B2     63.0      36
# 37         journals/mansci   2100.0   125312.0     B2     62.0      37
# 38            journals/ior   1480.0    54189.0     A1     61.0      38
# 39               conf/icra  16038.0   236265.0     A1     61.0      39
# 40         journals/comsur    583.0    19860.0     A1     61.0      40
# 41                 conf/or    809.0     2232.0     B4     61.0      41
# 42     journals/simulation   1374.0    14076.0     B3     61.0      42
# 43             conf/sigmod   3706.0   337960.0     A1     61.0      43
# 44               conf/eccv   3329.0   159515.0     A1     59.0      44
# 45              conf/isscc   1967.0    13365.0     B1     59.0      45
# 46                conf/smc   9388.0    28167.0     B2     58.0      46
# 47           journals/soco   1974.0    28145.0     B1     57.0      47
# 48                 conf/se    978.0      773.0   None     57.0      48
# 49      journals/computing   2617.0    31198.0     B1     57.0      49
# 50            journals/itp    375.0    12276.0   None     56.0      50
#
#                  Vkey Qualis  P-score    Rank             Vkey Qualis  \
# Rank
# 1           conf/cvpr     A1   3458.0       1        conf/iccv     A1
# 2       journals/pami     A1   1693.0       2        conf/cvpr     A1
# 3           conf/iccv     A1   1526.0       3    journals/ijcv     A1
# 4           conf/eccv     A1   1443.0       4        conf/eccv     A1
# 5           conf/icpr     A1   1144.0       5    journals/pami     A1
# 6           conf/icip     A1   1104.0       6     conf/emmcvpr   None
# 7       journals/ijcv     A1    776.0       7        conf/bmvc     A2
# 8           conf/bmvc     A2    680.0       8         conf/fgr   None
# 9         journals/pr     A1    572.0       9        conf/wacv     B1
# 10        conf/miccai     A1    540.0      10    journals/cviu     A1
# 11       journals/tip     A1    455.0      11         conf/icb   None
# 12      journals/cviu     A1    447.0      12        conf/accv   None
# 13          conf/nips     A1    437.0      13        conf/3dim     B1
# 14         conf/icmcs     B3    419.0      14     journals/tog     A1
# 15            conf/mm     A1    413.0      15     journals/ivc     A1
# 16          conf/accv   None    408.0      16        conf/icpr     A1
# 17        conf/icassp     A1    389.0      17         conf/mcs   None
# 18       journals/ivc     A1    328.0      18        conf/sspr     B1
# 19       journals/prl     A1    312.0      19   journals/cvgip   None
# 20       journals/tog     A1    304.0      20      conf/miccai     A1
# 21          conf/wacv     B1    298.0      21     journals/mva     B1
# 22          conf/icra     A1    292.0      22       conf/ismar     A2
# 23           conf/fgr   None    269.0      23          conf/mm     A1
# 24          conf/isbi     B1    244.0      24         conf/vmv   None
# 25          conf/iros     A1    221.0      25         conf/drr   None
# 26         conf/icdar     A2    201.0      26     journals/mia     A1
# 27      journals/tsmc   None    181.0      27     journals/tmm     A1
# 28      journals/tcsv     A1    177.0      28     journals/tip     A1
# 29          conf/dagm   None    168.0      29        conf/ipmi   None
# 30           conf/icb   None    165.0      30         conf/mir   None
# 31     journals/cvgip   None    159.0      31  conf/scalespace   None
# 32       journals/tmm     A1    154.0      32      journals/pr     A1
# 33       journals/cgf     A2    145.0      33        conf/scia   None
# 34          conf/aaai     A1    140.0      34  journals/ieeemm     A2
# 35          conf/icml     A1    138.0      35        conf/avss   None
# 36       journals/tmi     A1    128.0      36        conf/dagm   None
# 37      conf/siggraph     A2    125.0      37        conf/caip     B2
# 38       journals/mva     B1    119.0      38        conf/nips     A1
# 39          conf/sspr     B1    110.0      39       conf/icfhr   None
# 40           conf/mva     B3    107.0      40    journals/jmiv     B1
# 41           conf/pcm   None    106.0      41       conf/icdar     A2
# 42          conf/3dim     B1    103.0      42      conf/icvgip   None
# 43         conf/ismar     A2    100.0      43        conf/icmi     A2
# 44       conf/emmcvpr   None    100.0      44         conf/pcm   None
# 45          conf/caip     B2     98.0      45    journals/tifs   None
# 46    journals/ijprai     B1     97.0      46        conf/icip     A1
# 47       journals/mia     A1     96.0      47       conf/iciap     B1
# 48         conf/ijcai     A1     94.0      48         conf/mva     B3
# 49         conf/iciap     B1     92.0      49        conf/iswc     A1
# 50      journals/ijon     A1     84.0      50    journals/tcsv     A1
#
#          PS/VP
# Rank
# 1     0.506304
# 2     0.503055
# 3     0.444699
# 4     0.433464
# 5     0.333728
# 6     0.287356
# 7     0.268562
# 8     0.265810
# 9     0.263484
# 10    0.236008
# 11    0.233711
# 12    0.227298
# 13    0.168026
# 14    0.128216
# 15    0.127626
# 16    0.127508
# 17    0.126850
# 18    0.125000
# 19    0.113897
# 20    0.113852
# 21    0.105403
# 22    0.102145
# 23    0.099374
# 24    0.099225
# 25    0.097015
# 26    0.091691
# 27    0.090855
# 28    0.089006
# 29    0.088997
# 30    0.088154
# 31    0.085106
# 32    0.084816
# 33    0.083077
# 34    0.079022
# 35    0.078411
# 36    0.077206
# 37    0.076923
# 38    0.076882
# 39    0.075862
# 40    0.074499
# 41    0.072773
# 42    0.072327
# 43    0.071561
# 44    0.065432
# 45    0.064220
# 46    0.063878
# 47    0.063143
# 48    0.062137
# 49    0.059006
# 50    0.058706

# %% [markdown]
# ### conf/icip and conf/cvpr

# %%
subarea_seeds = {
    'Computer vision (Tests 2)':['conf/icip', 'conf/cvpr'],
}

rank(subarea_seeds).head(20)
# Out:
# conf/icip : OK
# conf/cvpr : OK
#                       Vkey  VPsize  Citations Qualis  H-Index    Rank  \
# Rank
# 1             journals/nar  5753.0   803995.0     B1    164.0       1
# 2                conf/balt   232.0      827.0   None    132.0       2
# 3             journals/cma  4572.0    33510.0   None    118.0       3
# 4              journals/pr  6744.0   201239.0     A1    118.0       4
# 5                conf/cvpr  6874.0   379400.0     A1    118.0       5
# 6             journals/cce  2581.0    35527.0   None    118.0       6
# 7             journals/cee  1272.0     4934.0   None    118.0       7
# 8      journals/neuroimage  6390.0   202819.0   None    117.0       8
# 9                conf/mmar   518.0      135.0   None    113.0       9
# 10              conf/icete   769.0     1194.0     B4     94.0      10
# 11    journals/information   150.0      275.0   None     93.0      11
# 12           journals/eswa  8936.0   109580.0     A1     89.0      12
# 13            journals/scl  1739.0    26654.0   None     89.0      13
# 14             journals/cm  1467.0     7672.0     A1     86.0      14
# 15     journals/automatica  7338.0   229957.0     A1     86.0      15
# 16          journals/pieee  1039.0    18961.0     A1     85.0      16
# 17         journals/sigpro  4742.0    50775.0     A1     84.0      17
# 18                conf/www  4501.0   120253.0     A1     83.0      18
# 19            journals/www   423.0     7421.0     B1     83.0      19
# 20             journals/or   324.0     1008.0   None     81.0      20
#
#                Vkey Qualis  P-score    Rank            Vkey Qualis     PS/VP
# Rank
# 1         conf/icip     A1   4675.0       1       conf/cvpr     A1  0.346087
# 2         conf/cvpr     A1   2379.0       2       conf/iccv     A1  0.339748
# 3       conf/icassp     A1   1906.0       3   journals/ijcv     A1  0.297994
# 4      journals/tip     A1   1357.0       4       conf/eccv     A1  0.285972
# 5        conf/icmcs     B3   1070.0       5        conf/pcs   None  0.278095
# 6     journals/pami     A1   1049.0       6       conf/icip     A1  0.270497
# 7         conf/icpr     A1   1032.0       7    journals/tip     A1  0.265454
# 8         conf/iccv     A1   1024.0       8   journals/tcsv     A1  0.250746
# 9         conf/eccv     A1    952.0       9       conf/mmsp     B2  0.233948
# 10    journals/tcsv     A1    756.0      10    conf/emmcvpr   None  0.232759
# 11       conf/iscas     A1    593.0      11    journals/tmm     A1  0.225959
# 12          conf/mm     A1    526.0      12        conf/fgr   None  0.212451
# 13      journals/pr     A1    520.0      13   journals/pami     A1  0.206781
# 14    journals/ijcv     A1    520.0      14       conf/vcip     B1  0.203976
# 15     journals/tsp     A1    489.0      15        conf/icb   None  0.203966
# 16        conf/bmvc     A2    458.0      16   journals/spic   None  0.194609
# 17      conf/miccai     A1    420.0      17       conf/bmvc     A2  0.180885
# 18     journals/tmm     A1    383.0      18       conf/wacv     B1  0.179487
# 19        conf/isbi     B1    382.0      19       conf/accv   None  0.179387
# 20        conf/mmsp     B2    368.0      20  journals/ejivp   None  0.167979

# %% [markdown]
# ### conf/cvpr and journals/pami and conf/icip

# %%
subarea_seeds = {
    'Computer vision (Tests 3)':['conf/cvpr', 'journals/pami', 'conf/icip'],
}

rank(subarea_seeds).head(50)
# Out:
# conf/cvpr : OK
# journals/pami : OK
# conf/icip : OK
#                       Vkey   VPsize  Citations Qualis  H-Index    Rank  \
# Rank
# 1             journals/nar   5753.0   803995.0     B1    164.0       1
# 2                conf/balt    232.0      827.0   None    132.0       2
# 3             journals/cce   2581.0    35527.0   None    118.0       3
# 4             journals/cee   1272.0     4934.0   None    118.0       4
# 5              journals/pr   6744.0   201239.0     A1    118.0       5
# 6             journals/cma   4572.0    33510.0   None    118.0       6
# 7                conf/cvpr   6874.0   379400.0     A1    118.0       7
# 8      journals/neuroimage   6390.0   202819.0   None    117.0       8
# 9                conf/mmar    518.0      135.0   None    113.0       9
# 10              conf/icete    769.0     1194.0     B4     94.0      10
# 11    journals/information    150.0      275.0   None     93.0      11
# 12           journals/eswa   8936.0   109580.0     A1     89.0      12
# 13            journals/scl   1739.0    26654.0   None     89.0      13
# 14             journals/cm   1467.0     7672.0     A1     86.0      14
# 15     journals/automatica   7338.0   229957.0     A1     86.0      15
# 16          journals/pieee   1039.0    18961.0     A1     85.0      16
# 17         journals/sigpro   4742.0    50775.0     A1     84.0      17
# 18            journals/www    423.0     7421.0     B1     83.0      18
# 19                conf/www   4501.0   120253.0     A1     83.0      19
# 20             journals/or    324.0     1008.0   None     81.0      20
# 21         journals/ploscb   3878.0    85175.0   None     80.0      21
# 22       conf/coordination    377.0     6017.0   None     78.0      22
# 23       journals/computer   4766.0   261329.0   None     76.0      23
# 24            conf/infocom   6943.0   350398.0     A1     76.0      24
# 25             journals/ml   1309.0   184440.0     A1     73.0      25
# 26          journals/bmcbi   7074.0   136587.0     A1     73.0      26
# 27             journals/is   1504.0    32461.0     A2     72.0      27
# 28              conf/dasip    258.0      161.0   None     70.0      28
# 29           journals/isci   7032.0   124049.0     A1     70.0      29
# 30           journals/bise    313.0     1427.0   None     70.0      30
# 31               conf/data    130.0       26.0   None     69.0      31
# 32               conf/icml   3294.0   290468.0     A1     69.0      32
# 33         journals/orgsci    621.0    19294.0   None     68.0      33
# 34               conf/nips   5684.0   404822.0     A1     66.0      34
# 35           journals/jocn   2068.0    89870.0   None     64.0      35
# 36     journals/interfaces    714.0     4506.0     B2     63.0      36
# 37         journals/mansci   2100.0   125312.0     B2     62.0      37
# 38     journals/simulation   1374.0    14076.0     B3     61.0      38
# 39                 conf/or    809.0     2232.0     B4     61.0      39
# 40             conf/sigmod   3706.0   337960.0     A1     61.0      40
# 41         journals/comsur    583.0    19860.0     A1     61.0      41
# 42               conf/icra  16038.0   236265.0     A1     61.0      42
# 43            journals/ior   1480.0    54189.0     A1     61.0      43
# 44              conf/isscc   1967.0    13365.0     B1     59.0      44
# 45               conf/eccv   3329.0   159515.0     A1     59.0      45
# 46                conf/smc   9388.0    28167.0     B2     58.0      46
# 47           journals/soco   1974.0    28145.0     B1     57.0      47
# 48      journals/computing   2617.0    31198.0     B1     57.0      48
# 49                 conf/se    978.0      773.0   None     57.0      49
# 50         conf/networking   1306.0     9360.0     B1     56.0      50
#
#                   Vkey Qualis  P-score    Rank             Vkey Qualis  \
# Rank
# 1            conf/icip     A1   4166.0       1        conf/cvpr     A1
# 2            conf/cvpr     A1   2664.0       2        conf/iccv     A1
# 3          conf/icassp     A1   1640.0       3    journals/ijcv     A1
# 4        journals/pami     A1   1440.0       4        conf/eccv     A1
# 5         journals/tip     A1   1292.0       5    journals/pami     A1
# 6            conf/iccv     A1   1157.0       6     journals/tip     A1
# 7            conf/icpr     A1   1116.0       7     conf/emmcvpr   None
# 8            conf/eccv     A1   1054.0       8        conf/icip     A1
# 9           conf/icmcs     B3    987.0       9    journals/tcsv     A1
# 10       journals/tcsv     A1    713.0      10         conf/pcs   None
# 11         journals/pr     A1    620.0      11         conf/icb   None
# 12       journals/ijcv     A1    577.0      12        conf/wacv     B1
# 13             conf/mm     A1    541.0      13        conf/mmsp     B2
# 14           conf/bmvc     A2    519.0      14         conf/fgr   None
# 15          conf/iscas     A1    487.0      15     journals/tmm     A1
# 16         conf/miccai     A1    452.0      16    journals/cviu     A1
# 17        journals/tsp     A1    407.0      17        conf/bmvc     A2
# 18       journals/cviu     A1    390.0      18        conf/vcip     B1
# 19           conf/isbi     B1    373.0      19        conf/accv   None
# 20        journals/tmm     A1    353.0      20    journals/spic   None
# 21           conf/mmsp     B2    334.0      21   journals/ejivp   None
# 22           conf/accv   None    329.0      22        conf/3dim     B1
# 23        journals/prl     A1    327.0      23       conf/icmcs     B3
# 24           conf/nips     A1    286.0      24          conf/mm     A1
# 25        journals/ivc     A1    277.0      25       conf/icdsc   None
# 26       journals/spic   None    246.0      26         conf/vmv   None
# 27           conf/wacv     B1    245.0      27   journals/cvgip   None
# 28           conf/icra     A1    238.0      28         conf/pcm   None
# 29        journals/tog     A1    231.0      29        conf/icpr     A1
# 30           conf/vcip     B1    213.0      30    journals/tifs   None
# 31            conf/fgr   None    211.0      31        conf/sspr     B1
# 32            conf/dcc     A2    207.0      32   journals/jvcir     B1
# 33            conf/pcm   None    203.0      33        conf/avss   None
# 34       journals/tsmc   None    192.0      34         conf/mir   None
# 35           conf/iros     A1    186.0      35     journals/ivc     A1
# 36        journals/tmi     A1    180.0      36         conf/dcc     A2
# 37      journals/ejasp     B1    176.0      37     journals/tog     A1
# 38      journals/cvgip   None    175.0      38       conf/ismar     A2
# 39        journals/tit     A1    168.0      39      conf/miccai     A1
# 40       conf/globecom     A1    159.0      40  journals/ieeemm     A2
# 41            conf/icb   None    154.0      41   journals/jstsp     A1
# 42     journals/sigpro     A1    135.0      42      journals/pr     A1
# 43       journals/tifs   None    132.0      43     journals/mia     A1
# 44      journals/jvcir     B1    132.0      44       conf/acivs     B2
# 45        journals/cgf     A2    129.0      45        conf/isbi     B1
# 46            conf/pcs   None    124.0      46     journals/mva     B1
# 47          conf/iciap     B1    120.0      47       conf/iciap     B1
# 48    conf/interspeech     A1    120.0      48        conf/caip     B2
# 49       journals/ijon     A1    119.0      49        conf/icmi     A2
# 50           conf/dagm   None    119.0      50    journals/jmiv     B1
#
#          PS/VP
# Rank
# 1     0.387547
# 2     0.383875
# 3     0.330659
# 4     0.316612
# 5     0.283856
# 6     0.252739
# 7     0.250000
# 8     0.241046
# 9     0.236484
# 10    0.236190
# 11    0.218130
# 12    0.216622
# 13    0.212333
# 14    0.208498
# 15    0.208260
# 16    0.205913
# 17    0.204976
# 18    0.184097
# 19    0.183287
# 20    0.161736
# 21    0.152231
# 22    0.150082
# 23    0.135465
# 24    0.130173
# 25    0.130137
# 26    0.125581
# 27    0.125358
# 28    0.125309
# 29    0.124387
# 30    0.121101
# 31    0.118182
# 32    0.117752
# 33    0.117108
# 34    0.108815
# 35    0.107782
# 36    0.107532
# 37    0.097427
# 38    0.096016
# 39    0.095298
# 40    0.095014
# 41    0.094134
# 42    0.091934
# 43    0.091691
# 44    0.090164
# 45    0.089363
# 46    0.087688
# 47    0.082361
# 48    0.074568
# 49    0.065056
# 50    0.064947

# %%
subarea_seeds = {
    'Computer vision (Tests 1)':['conf/cvpr', 'journals/pami', 'conf/iccv', 'conf/icpr', 'conf/icip'],
}

rank(subarea_seeds).head(20)
# Out:
# conf/cvpr : OK
# journals/pami : OK
# conf/iccv : OK
# conf/icpr : OK
# conf/icip : OK
#                       Vkey  VPsize  Citations Qualis  H-Index    Rank  \
# Rank
# 1             journals/nar  5753.0   803995.0     B1    164.0       1
# 2                conf/balt   232.0      827.0   None    132.0       2
# 3             journals/cce  2581.0    35527.0   None    118.0       3
# 4             journals/cee  1272.0     4934.0   None    118.0       4
# 5              journals/pr  6744.0   201239.0     A1    118.0       5
# 6                conf/cvpr  6874.0   379400.0     A1    118.0       6
# 7             journals/cma  4572.0    33510.0   None    118.0       7
# 8      journals/neuroimage  6390.0   202819.0   None    117.0       8
# 9                conf/mmar   518.0      135.0   None    113.0       9
# 10              conf/icete   769.0     1194.0     B4     94.0      10
# 11    journals/information   150.0      275.0   None     93.0      11
# 12           journals/eswa  8936.0   109580.0     A1     89.0      12
# 13            journals/scl  1739.0    26654.0   None     89.0      13
# 14             journals/cm  1467.0     7672.0     A1     86.0      14
# 15     journals/automatica  7338.0   229957.0     A1     86.0      15
# 16          journals/pieee  1039.0    18961.0     A1     85.0      16
# 17         journals/sigpro  4742.0    50775.0     A1     84.0      17
# 18            journals/www   423.0     7421.0     B1     83.0      18
# 19                conf/www  4501.0   120253.0     A1     83.0      19
# 20             journals/or   324.0     1008.0   None     81.0      20
#
#                Vkey Qualis  P-score    Rank           Vkey Qualis     PS/VP
# Rank
# 1         conf/icip     A1   3263.0       1      conf/iccv     A1  0.451228
# 2         conf/cvpr     A1   2940.0       2      conf/cvpr     A1  0.427699
# 3         conf/icpr     A1   1754.0       3  journals/ijcv     A1  0.400000
# 4     journals/pami     A1   1567.0       4      conf/eccv     A1  0.367378
# 5         conf/iccv     A1   1360.0       5   conf/emmcvpr   None  0.310345
# 6         conf/eccv     A1   1223.0       6  journals/pami     A1  0.308890
# 7       conf/icassp     A1   1143.0       7       conf/icb   None  0.281870
# 8      journals/tip     A1   1070.0       8       conf/fgr   None  0.269763
# 9        conf/icmcs     B3    887.0       9      conf/bmvc     A2  0.255924
# 10      journals/pr     A1    814.0      10      conf/accv   None  0.242340
# 11    journals/ijcv     A1    698.0      11     conf/gbrpr   None  0.241525
# 12        conf/bmvc     A2    648.0      12      conf/wacv     B1  0.237843
# 13          conf/mm     A1    579.0      13  journals/cviu     A1  0.236008
# 14    journals/tcsv     A1    490.0      14      conf/sspr     B1  0.225000
# 15      conf/miccai     A1    469.0      15   journals/tip     A1  0.209311
# 16    journals/cviu     A1    447.0      16       conf/mcs   None  0.198732
# 17        conf/accv   None    435.0      17      conf/acpr   None  0.197640
# 18     journals/prl     A1    431.0      18      conf/icpr     A1  0.195497
# 19        conf/isbi     B1    368.0      19      conf/icip     A1  0.188798
# 20     journals/ivc     A1    337.0      20      conf/3dim     B1  0.177814
