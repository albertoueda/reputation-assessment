# %% [markdown]
# Created by Alberto Ueda on 2017-03-11

# %% [markdown]
# ## Precision-Recall Curves

# %%
show_me('Information retrieval', 'ir-students', 2)

# %%
show_me('Database', 'db', 1)

# %%
show_me('Data mining', 'dm', 2)

# %%
show_me('Knowledge management', 'km', 2)
